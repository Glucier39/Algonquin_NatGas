# %% [markdown]
# ## Graphing Intraday Prices for WTI and Brent during weather events
#
# ### Building off of tx_disaster_raw.csv

# %%
#VZDSBRQDYC6PHJLU API 
# !pip install alpha_vantage pandas matplotlib
from alpha_vantage.timeseries import TimeSeries
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: alpha_vantage in /opt/anaconda3/envs/envs/lib/python3.13/site-packages (3.0.0)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/envs/lib/python3.13/site-packages (2.3.2)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/envs/lib/python3.13/site-packages (3.10.6)
# Requirement already satisfied: aiohttp in /opt/anaconda3/envs/envs/lib/python3.13/site-packages (from alpha_vantage) (3.12.15)
# Requirement already satisfied: requests in /opt/anaconda3/envs/envs/lib/python3.13/site-packages (from alpha_vantage) (2.32.5)
# Requirement already satisfied: numpy>=1.26.0 in /opt/anaconda3/envs/envs/lib/python3.13/site-packages (from pandas) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/envs/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/envs/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/envs/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/envs/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/envs/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/envs/lib/python3.13/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/envs/lib/python3.13/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/envs/lib/python3.13/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/envs/lib/python3.13/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/envs/lib/python3.13/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/envs/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/anaconda3/envs/envs/lib/python3.13/site-packages (from aiohttp->alpha_vantage) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/anaconda3/envs/envs/lib/python3.13/site-packages (from aiohttp->alpha_vantage) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/envs/envs/lib/python3.13/site-packages (from aiohttp->alpha_vantage) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/envs/envs/lib/python3.13/site-packages (from aiohttp->alpha_vantage) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/envs/envs/lib/python3.13/site-packages (from aiohttp->alpha_vantage) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/anaconda3/envs/envs/lib/python3.13/site-packages (from aiohttp->alpha_vantage) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/anaconda3/envs/envs/lib/python3.13/site-packages (from aiohttp->alpha_vantage) (1.18.0)
# Requirement already satisfied: idna>=2.0 in /opt/anaconda3/envs/envs/lib/python3.13/site-packages (from yarl<2.0,>=1.17.0->aiohttp->alpha_vantage) (3.7)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/envs/lib/python3.13/site-packages (from requests->alpha_vantage) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/envs/lib/python3.13/site-packages (from requests->alpha_vantage) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/envs/lib/python3.13/site-packages (from requests->alpha_vantage) (2025.8.3)
